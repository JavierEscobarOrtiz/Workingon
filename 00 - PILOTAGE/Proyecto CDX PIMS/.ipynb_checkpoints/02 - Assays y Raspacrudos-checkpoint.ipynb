# %% [markdown]
# # Librerias

# %%
# %config IPCompleter.greedy=True

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pyodbc
import seaborn as sns
from pyodbc import ProgrammingError
from datetime import datetime

# Preprocesado y modelado
# ==============================================================================
from sklearn.preprocessing import normalize
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram
from sklearn.preprocessing import scale
from sklearn.metrics import silhouette_score

import cdx_pilotage.pims_functions as pf
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Cargar Assay

# %%
def cargar_excel_assays_crudos(excel, hoja):
 
    df_assays = pd.read_excel(excel, sheet_name = hoja, header = 6)

    for col in list(df_assays.columns):
        if df_assays[col].notnull().sum() == 0:
            df_assays.drop([col], axis=1, inplace=True)

    df_assays = df_assays[df_assays["TEXT"].notnull()]

    print("Cargado df assays:")
    print(df_assays.shape)
    display(df_assays.head(10))
    print("==============================")
    
    return df_assays

# %%
excel_assays = r"C:\Users\JESCOBARO\Desktop\CDX_PIMS\GlobalModel_CEPSA_2.12\Algeciras\Algeciras Assays.xlsx"
hoja_excel_SCD2 = "ASSAYS1"

df_assays_cd1 = cargar_excel_assays_crudos(excel_assays, hoja_excel_SCD2)
# Out:
# Cargado df assays:
# (519, 161)
#    ROWNAMES                                     TEXT  !*?       !Type  \
# 0         *                                     Name  NaN           1
# 1         *                                Reference  NaN           2
# 2         *                               Assay Date  NaN           6
# 3         *                                      API  NaN           7
# 4         *                           Den@15°C(g/cc)  NaN           8
# 5         *                                  Sul(%w)  NaN           9
# 7         *              Standard Capacity, kBbl/day  NaN  117.241376
# 8         *                Standard Capacity, kt/day  NaN          16
# 9         *                    Capacity factor Feed   NaN         NaN
# 10        *  Capacity factor Stabilizer < 3.4 kt/day  NaN         3.4
#
#        !Prop !Lookup !Stream !Sheet !Lookup.1                 ARI  \
# 0        NaN     NaN     NaN    NaN       NaN  Atm. Res. Imported
# 1        NaN     NaN     NaN    NaN       NaN
# 2        NaN     NaN     NaN    NaN       NaN
# 3        NaN     NaN     NaN    NaN       NaN
# 4        NaN     NaN     NaN    NaN       NaN
# 5        NaN     NaN     NaN    NaN       NaN
# 7        NaN     NaN     NaN    NaN       NaN
# 8   7.327586     NaN     NaN    NaN       NaN
# 9        NaN     NaN     NaN    NaN       NaN
# 10       NaN     NaN     NaN    NaN       NaN
#
#                     ASG            ABO            AGB             AJE  \
# 0         AASGARD BLEND            ABO         AGBAMI             AJE
# 1   CEPSA AASGARD BLEND      CEPSA ABO   CEPSA AGBAMI       CEPSA AJE
# 2     01 noviembre 2017  01 enero 2020  27 junio 2014  19 agosto 2016
# 3                  49.5           40.7           0.04            41.5
# 4                0.7814         0.8211         0.7868          0.8174
# 5                  0.18            0.1           0.04            0.03
# 7
# 8
# 9              1.101021       1.047787       1.093465         1.05253
# 10             2.183839       1.329703       1.479203         0.89289
#
#                 AKP                ALJ                 AVH            AMB  \
# 0              AKPO            AL JURF        ALVHEIMBLEND   AMENAM BLEND
# 1        CEPSA AKPO      CEPSA AL JURF  CEPSA ALVHEIMBLEND   CEPSA AMENAM
# 2   09 febrero 2015  01 diciembre 2003  05 septiembre 2013  01 abril 2004
# 3              45.8              29.82                34.9          38.98
# 4            0.7977             0.8766                0.85         0.8296
# 5              0.07                1.9                0.17           0.09
# 7
# 8
# 9          1.078523           0.981449            1.012162       1.037051
# 10         1.240024           0.548164            0.701489       1.203752
#
#               AXN            ANT                  ARL                 ARM  \
# 0            AMNA          ANTAN        ARABIA LIGERO        ARABIA MEDIO
# 1      CEPSA AMNA    CEPSA ANTAN  CEPSA ARABIA LIGERO  CEPSA ARABIA MEDIO
# 2   01 abril 2004  07 marzo 2018   01 septiembre 1997     01 octubre 1990
# 3           36.47           26.2                32.95               31.06
# 4           0.842         0.8968                 0.86                0.87
# 5            0.11            0.3                 2.01                 2.5
# 7
# 8
# 9        1.021779       0.959342             1.000393            0.988894
# 10        0.58867       0.342361             0.751458            0.770437
#
#               ASE            ATA              AZE              NOD  \
# 0           ASENG          ATAPU   Azeri CIC 2020           BAKKEN
# 1     CEPSA ASENG    CEPSA ATAPU   Azeri CIC 2020     CEPSA BAKKEN
# 2   01 enero 2012  01 junio 2020  septiembre 2020  20 febrero 2018
# 3            29.3          0.396            38.77             43.4
# 4          0.8795         0.8886           0.8305           0.8086
# 5            0.25          0.394             0.15              0.1
# 7
# 8
# 9        0.978213       0.968195         1.035928         1.063985
# 10       0.344783        0.45866         1.002855         1.424651
#
#                    BAL                  BAP            BAU                BLA  \
# 0         BASRA LIGERO        BASRAH PESADO          BAUNA          BLACKHAWK
# 1   CEPSA BASRA LIGERO  CEPSA BASRAH PESADO    CEPSA BAUNA    CEPSA BLACKHAWK
# 2        30 junio 2008        01 abril 2015  21 enero 2020  14 noviembre 2014
# 3                 29.5                  4.2           33.2               52.2
# 4               0.8785               0.9119         0.8589             0.7703
# 5                 3.17                  4.2          0.238               0.03
# 7
# 8
# 9             0.979326             0.943456       1.001674           1.116887
# 10            0.699816             0.594268       0.743229           1.561139
#
#                    BON                 BOL                BRR  \
# 0                BONGA        BONNY LIGERO        BRASS RIVER
# 1          CEPSA BONGA  CEPSA BONNY LIGERO  CEPSA BRASS RIVER
# 2   22 septiembre 2017     01 febrero 2012      01 junio 2011
# 3                 27.7               36.55               0.18
# 4               0.8883               0.842             0.8379
# 5                 0.25                0.17               0.18
# 7
# 8
# 9             0.968522            1.021779           1.026779
# 10            0.516483            1.309852           1.162592
#
#                    BGA                BBB                BMS  \
# 0                BREGA        BRENT BLEND        BRYAN MOUND
# 1          CEPSA BREGA  CEPSA BRENT BLEND  CEPSA BRYAN MOUND
# 2   01 septiembre 2018      01 junio 1998    28 febrero 2018
# 3                 0.19               38.9               40.7
# 4               0.8139               0.83             0.8215
# 5                 0.19               0.35               0.44
# 7
# 8
# 9             1.057056           1.036552           1.047277
# 10            1.142426           1.139245           1.393313
#
#                   BUA            BUZ                   CAE                CEB  \
# 0          BU ATTIFEL         BUZIOS        CABINDA EXPORT        CEIBA BLEND
# 1    CEPSA BU ATTIFEL   CEPSA BUZIOS  CEPSA CABINDA EXPORT  CEPSA CEIBA BLEND
# 2   01 diciembre 1996  01 abril 2020        01 agosto 1994       01 mayo 2007
# 3                42.3           0.28                  32.7               30.7
# 4               0.814         0.8825                0.8615             0.8721
# 5              0.0171           0.28                  0.12               0.46
# 7
# 8
# 9            1.056926       0.974887              0.998651           0.986513
# 10           0.544172        0.56652              0.614072           0.667614
#
#                CHE            CJB                CLA             CLO  \
# 0         CHELEKEN       CJ Blend              CLAIR            Clov
# 1   CEPSA CHELEKEN       CJ Blend        Cepsa CLAIR      Cepsa Clov
# 2    01 marzo 2012  10 enero 2021  01 diciembre 2010  27 agosto 2014
# 3             0.08           35.7               23.6            31.8
# 4           0.8226         0.8457             0.9121          0.8663
# 5             0.08            0.1               0.47            0.26
# 7
# 8
# 9         1.045876       1.017309            0.94325        0.993118
# 10        0.892109       0.925356           0.376419        0.639323
#
#                 CPB              DAL                 DAB            DJE  \
# 0         CPC BLEND            Dalia        DAS BLEND CI          DJENO
# 1   CEPSA CPC BLEND  CEPSA DALIA Tfe  CEPSA DAS BLEND CI    CEPSA DJENO
# 2     06 julio 2015    01 marzo 2013     01 octubre 2014  30 enero 2018
# 3              45.8             23.3               39.72           26.4
# 4            0.7978           0.9144              0.8264         0.8957
# 5              0.55             0.44                1.09           0.54
# 7
# 8
# 9          1.078388         0.940877            1.041067        0.96052
# 10         1.598759         0.169958            1.059891       0.416698
#
#                     DSW            DUC            CEP               EAF  \
# 0        DOMESTIC SWEET            DUC             EA        EAGLE FORD
# 1   CEPSA DOMESTICSWEET      CEPSA DUC       CEPSA EA  CEPSA EAGLE FORD
# 2         01 abril 2016  14 enero 2005  08 junio 2015     05 julio 2016
# 3                  41.1          33.55           0.12              55.4
# 4                0.8195         0.8569         0.8801            0.7566
# 5                   0.4           0.25           0.12              0.04
# 7
# 8
# 9              1.049833       1.004012       0.977546          1.137111
# 10             1.408775       0.906825       0.388054          2.106796
#
#                     E44                  E46                 KIR  \
# 0         Eagle Ford 44        Eagle Ford 45                EBCO
# 1   CEPSA EAGLE FORD 44  CEPSA Eagle Ford 45          CEPSA EBCO
# 2         27 enero 2020        01 abril 2019  27 septiembre 2016
# 3                  0.34                 0.11                30.3
# 4                 0.806               0.7982              0.8739
# 5                  0.34                 0.11                2.73
# 7
# 8
# 9              1.067417             1.077848            0.984481
# 10             1.349146             1.207394            0.784549
#
#                   EBO                EGI            EKO               ENT  \
# 0               EBOME              EGINA        EKOFISK        ENTERPRISE
# 1         CEPSA EBOME        CEPSA EGINA  Cepsa EKOFISK  CEPSA ENTERPRISE
# 2   14 diciembre 2015  06 diciembre 2017  12 enero 2011   01 octubre 2015
# 3               33.23               0.17           38.4              0.05
# 4              0.8382             0.8907         0.8324            0.7689
# 5                0.08               0.17           0.22              0.05
# 7
# 8
# 9            1.026411           0.965912       1.033563           1.11892
# 10           1.191919           0.226101       1.132834          1.734087
#
#                ERH               ESH                ESS            ESC  \
# 0             ERHA        ES Sharara           ES SIDER       ESCRAVOS
# 1       CEPSA ERHA  CEPSA Es Sharara     CEPSA ES SIDER       ESCRV322
# 2   01 agosto 2018     01 enero 2004  01 diciembre 1993  18 enero 2017
# 3             34.8              0.07               36.6           0.17
# 4           0.8502            0.8103             0.8418         0.8639
# 5             0.23              0.07                0.4          0.175
# 7
# 8
# 9         1.011924          1.061752           1.022022       0.995877
# 10        0.797918          1.330577            0.88588       0.688772
#
#               ESP                FLG                FOR                   FRL  \
# 0          ESPOIR        Flotta Gold           FORCADOS        FORCADOS LIGHT
# 1    CEPSA ESPOIR  CEPSA Flotta Gold     CEPSA FORCADOS  CEPSA FORCADOS LIGHT
# 2   09 enero 2018  01 diciembre 2014  04 noviembre 2013        31 agosto 2016
# 3             0.3               36.4               32.6                 40.87
# 4          0.8668             0.8426              0.862                0.8209
# 5            0.29               0.66               0.14                  0.11
# 7
# 8
# 9        0.992545           1.021051           0.998072              1.048042
# 10       0.672751           0.942061           0.729228              1.603343
#
#                     FOB              GKR             GDG             GIR  \
# 0         FORTIES BLEND        GINA KROG        GINDUNGO        GIRASSOL
# 1   CEPSA FORTIES BLEND  CEPSA GINA KROG  CEPSA GINDUNGO  CEPSA GIRASSOL
# 2     04 noviembre 2011    27 junio 2018   13 abril 2018   01 abril 2002
# 3                  38.7             36.3              32           31.57
# 4                 0.831           0.8429           0.865          0.8677
# 5                  0.79             0.31            0.58            0.32
# 7
# 8
# 9              1.035304         1.020688         0.99461        0.991515
# 10             1.234826         1.133368        0.722842        0.603906
#
#                    GLT                GRA            GUA             GUL  \
# 0         GOLIAT BLEND        GRANE BLEND        GUAFITA        Gullfaks
# 1   CEPSA GOLIAT BLEND  CEPSA GRANE BLEND  CEPSA GUAFITA  CEPSA GULLFAKS
# 2        06 marzo 2015      01 marzo 2019  17 marzo 2007  15 agosto 2014
# 3                 40.3               0.59           26.9            0.22
# 4               0.8231             0.8814         0.8928          0.8291
# 5                 0.14               0.59           0.87            0.22
# 7
# 8
# 9             1.045241           0.976104        0.96364        1.037677
# 10            1.170921           0.612228       0.398617        1.113535
#
#                HIB            IRA                IRL                IRP  \
# 0         HIBERNIA        IRACEMA        IRAN LIGERO        IRAN PESADO
# 1   CEPSA HIBERNIA  Cepsa Iracema  CEPSA IRAN LIGERO  CEPSA IRAN PESADO
# 2    01 julio 2017   29 mayo 2020      24 junio 2016      21 junio 2016
# 3             0.53           0.28               33.4               2.02
# 4           0.8554         0.8613             0.8579             0.8788
# 5             0.53           0.28               1.56               2.02
# 7
# 8
# 9         1.005773       0.998883           1.002842           0.978992
# 10        0.769617       0.723556           0.870152           0.705268
#
#                IST                   JSV                JON  \
# 0         ISTMO 32        Johan Sverdrup        JONES CREEK
# 1   CEPSA ISTMO 32  CEPSA JOHAN SVERDRUP  CEPSA JONES CREEK
# 2     01 mayo 2014          febrero 2019  13 noviembre 2018
# 3            32.58                    28               29.8
# 4           0.8624                0.8867             0.8768
# 5             1.58                   0.8               0.18
# 7
# 8
# 9         0.997609              0.970269           0.981225
# 10        0.803958              0.546453           0.521408
#
#                     JUB                   KIB                KOL  \
# 0         Jubilee Blend        Kissanje Blend               KOLE
# 1   CEPSA Jubilee Blend  Cepsa Kissanje Blend         CEPSA KOLE
# 2        27 agosto 2019         01 julio 2019  01 diciembre 2013
# 3                 37.41                  0.37               28.5
# 4                0.8373                0.8785             0.8837
# 5                   0.3                  0.37               0.42
# 7
# 8
# 9              1.027515              0.979326           0.973563
# 10              1.06763              0.580573           0.507061
#
#                   KOM                  KUE                 LAE  \
# 0         KOLE MARINE        KUWAIT EXPORT        LAVAN EXPORT
# 1   CEPSA KOLE MARINE  CEPSA KUWAIT EXPORT  CEPSA LAVAN EXPORT
# 2       11 junio 2018         11 mayo 2008      16 agosto 2008
# 3                0.55                 2.74                35.5
# 4              0.8824               0.8736              0.8472
# 5                0.55                 2.74                 1.6
# 7
# 8
# 9            0.974998             0.984819            1.015507
# 10           0.591221             0.716381            0.974332
#
#                       LIV            LOK                 LUB            LUL  \
# 0         LIVERPOOL BLEND         LOKELE        LUCINA BLEND           LULA
# 1   CEPSA LIVERPOOL BLEND   CEPSA LOKELE  CEPSA LUCINA BLEND     CEPSA LULA
# 2                       0  17 julio 2019   01 diciembre 2006  01 junio 2012
# 3                0.313666           0.33                  35           30.5
# 4                  0.8088         0.9076                0.85         0.8731
# 5                    0.36           0.33                0.07           0.35
# 7
# 8
# 9                1.063721       0.947926            1.012162       0.985383
# 10               1.197169       0.423149            0.711086       0.581837
#
#               MAN                 MAR            MAY                 MDN  \
# 0          MANDJI                MARS           MAYA            MEDANITO
# 1    CEPSA MANDJI          CEPSA MARS     CEPSA MAYA      CEPSA MEDANITO
# 2   01 junio 1995  10 septiembre 2012  01 julio 1992  13 septiembre 2018
# 3            29.6                28.8           21.6                40.2
# 4           0.878              0.8822          0.924              0.8238
# 5            1.06                 1.8           3.34                0.33
# 7
# 8
# 9        0.979884            0.975219       0.931102            1.044353
# 10       0.567783            0.699762       0.497281            1.341029
#
#                   MEL            MRO              ME3                    MUR  \
# 0            MELLITAH           MERO          MESA 30        Murban Exp. Bld
# 1      CEPSA MELLITAH     CEPSA MERO    CEPSA MESA 30  CEPSA Murban Exp. Bld
# 2   29 noviembre 2017  01 junio 2018  01 octubre 1998        01 octubre 2009
# 3                43.7           28.5               30                   39.9
# 4              0.8072         0.8836           0.8765                 0.8252
# 5                0.11           0.33             1.08                   0.81
# 7
# 8
# 9             1.06583       0.973674         0.981561               1.042581
# 10           1.522166       0.487171         0.623424                1.02392
#
#               NEM             NKO                 OGU            OKO  \
# 0           NEMBA          Nkossa            OGUENDJO          OKONO
# 1     CEPSA NEMBA    Cepsa Nkossa  CEPSA OGUENDJO (c)    CEPSA OKONO
# 2   01 enero 2013  25 agosto 2017       01 abril 2019  09 abril 2011
# 3            37.9            0.04                35.6           40.5
# 4           0.837          0.8133              0.8462         0.8223
# 5            0.27            0.04                0.75           0.06
# 7
# 8
# 9        1.027883        1.057836            1.016708       1.046258
# 10       1.122953        1.102911            0.927132       1.227931
#
#                   OKR            OKW              OBE              OLE  \
# 0         OKORO LIGHT         OKWORI        OKWUIBOME        OLOMBENDO
# 1   CEPSA OKORO LIGHT   CEPSA OKWORI  CEPSA OKWUIBOME  CEPSA OLOMBENDO
# 2     06 febrero 2018  01 junio 2005  01 febrero 2016    01 marzo 2011
# 3               36.43          36.81              0.1             35.2
# 4              0.8421         0.8407           0.8335           0.8486
# 5                 0.1           0.11              0.1             0.12
# 7
# 8
# 9            1.021658       1.023359         1.032199         1.013832
# 10           0.885107       0.732237         1.195133         0.784825
#
#                   OME            OSE              OTA                 PAZ  \
# 0         OMAN EXPORT        OSEBERG         OTAKIKPO             Pazflor
# 1   CEPSA OMAN EXPORT  CEPSA OSEBERG   CEPSA OTAKIKPO       Cepsa PAzflor
# 2       01 marzo 2017   20 mayo 2016  01 octubre 2017  16 septiembre 2011
# 3                30.5           39.6             41.2               25.67
# 4              0.8731         0.8268           0.8191              0.8998
# 5                1.52            0.2             0.06                0.39
# 7
# 8
# 9            0.985383       1.040564         1.050345            0.956143
# 10           0.614349       1.217437         1.180392             0.36099
#
#                   PEN              PIE             PLU              QAR  \
# 0          PENNINGTON           PIERCE        PLUTONIO            QARUN
# 1    CEPSA PENNINGTON     CEPSA PIERCE  CEPSA PLUTONIO  CEPSA QARUN NEW
# 2   11 noviembre 2016  12 febrero 2018   01 julio 2017    26 junio 2019
# 3                37.6            40.17            0.32         0.361059
# 4              0.8365            0.824          0.8682           0.8548
# 5                 0.1             0.16            0.32             0.37
# 7
# 8
# 9            1.028497         1.044099        0.990944         1.006479
# 10           1.097811         1.175641        0.726816         0.618166
#
#                QUI                RAB                         REB  \
# 0         QUA IBOE         RABI BLEND        RUSSIAN EXPORT BLEND
# 1   CEPSA QUA IBOE   CEPSA RABI BLEND  CEPSA RUSSIAN EXPORT BLEND
# 2    01 enero 2018  01 diciembre 2003               01 enero 2002
# 3             37.6               33.4                        31.8
# 4           0.8365              0.858                      0.8662
# 5              0.1               0.07                        1.32
# 7
# 8
# 9         1.028497           1.002725                    0.993232
# 10        1.059467            0.36182                    0.722043
#
#                     SAB            SKF             SAP                SMS  \
# 0         SAHARAN BLEND        SANKOFA        SAPINHOA              SARIR
# 1   CEPSA SAHARAN BLEND  CEPSA SANKOFA  CEPSA SAPINHOA        CEPSA SARIR
# 2            marzo 2021  14 julio 2017      enero 2013  17 noviembre 2015
# 3                 45.84           28.9            29.7               37.4
# 4                0.7972         0.8816          0.8771             0.8373
# 5                0.0775            0.3           0.363               0.15
# 7
# 8
# 9                1.0792       0.975882        0.980889           1.027515
# 10             1.469335       0.493921        0.605367           0.835403
#
#               SAT               SA1                 SCH                   SIL  \
# 0         SATURNO        SAXI BLEND        Schiehallion        SIBERIAN LIGHT
# 1   CEPSA SATURNO  CEPSA SAXI BLEND  CEPSA SCHIEHALLION  CEPSA SIBERIAN LIGHT
# 2   01 marzo 2013      01 mayo 2008   21 noviembre 2013    01 septiembre 1995
# 3            25.6              32.7                0.46                  35.1
# 4          0.9001            0.8611              0.9025                0.8486
# 5            0.83               0.3                0.46                  0.57
# 7
# 8
# 9        0.955825          0.999115            0.953283              1.013832
# 10       0.531841          0.720274            0.173136              0.825277
#
#               SIR            SNG            SOR              STA  \
# 0           SIRRI        SONGKLA       SOROOSH         STATFJORD
# 1     CEPSA SIRRI  CEPSA SONGKLA  CEPSA SOROOSH  CEPSA STATFJORD
# 2   07 marzo 2017              0  04 junio 2002    19 abril 2010
# 3              33              0          19.72             39.5
# 4          0.8599          0.887         0.9352            0.827
# 5            1.83              0           3.15             0.22
# 7
# 8
# 9        1.000509       0.969941       0.919951         1.040312
# 10       0.882018       0.107843       0.386735         1.147135
#
#                 SUR              TEN               TER                    TIE  \
# 0            SURURU        TEN BLEND        TERRA NOVA        TI Epic/GrayOak
# 1      CEPSA SURURU  CEPSA TEN BLEND  CEPSA TERRA NOVA  CEPSA TI Epic/GrayOak
# 2   01 octubre 2019    01 enero 2017     01 junio 2014        21 febrero 2017
# 3              0.32             33.8              34.2                   42.6
# 4            0.8845           0.8554             0.854                 0.8124
# 5              0.32             0.43              0.52                  0.094
# 7
# 8
# 9          0.972683         1.005773          1.007421               1.059008
# 10         0.510565          0.83717          0.818053               1.260065
#
#                  TIP                TRO                       UZE  \
# 0         TI Permian        TROLL BLEND        Upper Zakum Exp Bl
# 1   CEPSA TI Permian  CEPSA TROLL BLEND  CEPSA UPPER ZAKUM EXP BL
# 2    21 febrero 2017      06 abril 2018             01 enero 2009
# 3               43.1               35.4                      1.89
# 4             0.8101             0.8472                    0.8542
# 5              0.176               0.18                      1.89
# 7
# 8
# 9           1.062014           1.015507                  1.007186
# 10           1.27881           1.111733                  0.882533
#
#                   URL               USB                VAR             VAS  \
# 0         URAL LIGERO        USAN Blend           VARANDEY        VASCONIA
# 1   CEPSA URAL LIGERO  CEPSA USAN BLEND     CEPSA VARANDEY  CEPSA VASCONIA
# 2       01 marzo 1988      01 mayo 2019  01 noviembre 2012   01 enero 2014
# 3                  34                28               35.1           28.81
# 4              0.8545            0.8865             0.8492          0.8827
# 5                 1.3               0.3               0.61            0.78
# 7
# 8
# 9            1.006832          0.970488           1.013116        0.974666
# 10           0.856109          0.548698           0.665843        0.846603
#
#                         WTC                    WML  \
# 0         WEST TEXAS CACTUS  West Texas Light 46.3
# 1   CEPSA WEST TEXAS CACTUS               WTXLT463
# 2           21 febrero 2017        30 octubre 2018
# 3                      43.1               0.058846
# 4                    0.8101                 0.7955
# 5                      0.14                   0.06
# 7
# 8
# 9                  1.062014               1.081506
# 10                 1.427104               1.437015
#
#                               WCS                   WED                 WHC  \
# 0          Western Canad'n Select        WESTERN DESERT        WHITE CLIFFS
# 1   CEPSA Western Canadian Select  CEPSA WESTERN DESERT  CEPSA WHITE CLIFFS
# 2               01 diciembre 2011         01 enero 2016   02 noviembre 2015
# 3                             3.4                  41.1                49.4
# 4                          0.9298                0.8194              0.7819
# 5                             3.4                  0.32                0.06
# 7
# 8
# 9                        0.925294              1.049961            1.100317
# 10                       0.609145              1.408848            1.737798
#
#                  WHR              WTL            YOH                 ZAB  \
# 0         WHITE ROSE        WTI LIGHT           YOHO        ZAFIRO BLEND
# 1   CEPSA WHITE ROSE  CEPSA WTI LIGHT     CEPSA YOHO  CEPSA ZAFIRO BLEND
# 2      01 enero 2014    31 enero 2019  01 enero 2018      01 agosto 2008
# 3               31.7             48.6           40.5                30.6
# 4              0.867           0.7854         0.8225              0.8725
# 5               0.26             0.03           0.06                0.27
# 7
# 8
# 9           0.992316         1.095414       1.046004            0.986061
# 10          0.677252          1.70863        1.26055            0.749258
#
#                    ZAE                ZAR             ZUE  Unnamed: 154  \
# 0         ZAIRE EXPORT         ZARZAITINE        ZUEITINA           NaN
# 1   CEPSA ZAIRE EXPORT   CEPSA ZARZAITINE  CEPSA ZUEITINA           NaN
# 2        01 junio 1994  01 noviembre 2019               0           NaN
# 3                 31.4              43.97            41.3           NaN
# 4               0.8686             0.8057          0.8185           NaN
# 5                 0.12               0.08            0.28           NaN
# 7                                                                   NaN
# 8                                                                   NaN
# 9             0.990488           1.067814        1.051115           NaN
# 10            0.559235            1.30777        1.059152           NaN
#
#     Unnamed: 155  Unnamed: 156  Unnamed: 157  Unnamed: 158  Unnamed: 159  \
# 0            NaN           NaN           NaN           NaN           NaN
# 1            NaN           NaN           NaN           NaN           NaN
# 2            NaN           NaN           NaN           NaN           NaN
# 3            NaN           NaN           NaN           NaN           NaN
# 4            NaN           NaN           NaN           NaN           NaN
# 5            NaN           NaN           NaN           NaN           NaN
# 7            NaN           NaN           NaN           NaN           NaN
# 8            NaN           NaN           NaN           NaN           NaN
# 9            NaN           NaN           NaN           NaN           NaN
# 10           NaN           NaN           NaN           NaN           NaN
#
#     Unnamed: 160
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# ==============================

# %%
excel_assays = r"C:\Users\JESCOBARO\Desktop\CDX_PIMS\GlobalModel_CEPSA_2.12\Algeciras\Algeciras Assays.xlsx"
hoja_excel_SCDb = "ASSAYS2"

df_assays = cargar_excel_assays_crudos(excel_assays, hoja_excel_SCDb)
# Out:
# Cargado df assays:
# (523, 153)
#    ROWNAMES                                     TEXT  !*?      !Type  \
# 0         *                                     Name  NaN          1
# 1         *                                Reference  NaN          2
# 2         *                               Assay Date  NaN          6
# 3         *                                      API  NaN          7
# 4         *                           Den@15°C(g/cc)  NaN          8
# 5         *                                  Sul(%w)  NaN          9
# 7         *              Standard Capacity, kBbl/day  NaN  135.26159
# 8         *                Standard Capacity, kt/day  NaN     18.459
# 9         *                    Capacity factor Feed   NaN        NaN
# 10        *  Capacity factor Stabilizer < 2.7 kt/day  NaN        2.7
#
#        !Prop !Lookup !Stream !Sheet !Lookup.1            ABO            AGB  \
# 0        NaN     NaN     NaN    NaN       NaN            ABO         AGBAMI
# 1        NaN     NaN     NaN    NaN       NaN      CEPSA ABO   CEPSA AGBAMI
# 2        NaN     NaN     NaN    NaN       NaN  01 enero 2020  27 junio 2014
# 3        NaN     NaN     NaN    NaN       NaN           40.7           0.04
# 4        NaN     NaN     NaN    NaN       NaN         0.8211         0.7868
# 5        NaN     NaN     NaN    NaN       NaN            0.1           0.04
# 7        NaN     NaN     NaN    NaN       NaN            NaN            NaN
# 8   7.327677     NaN     NaN    NaN       NaN            NaN            NaN
# 9        NaN     NaN     NaN    NaN       NaN       1.047774       1.093451
# 10       NaN     NaN     NaN    NaN       NaN       1.780957       2.043101
#
#                AJE              AKP                ALJ            AMB  \
# 0              AJE             AKPO            AL JURF   AMENAM BLEND
# 1        CEPSA AJE       CEPSA AKPO      CEPSA AL JURF   CEPSA AMENAM
# 2   19 agosto 2016  09 febrero 2015  01 diciembre 2003  01 abril 2004
# 3             41.5             45.8              29.82          38.98
# 4           0.8174           0.7977             0.8766         0.8296
# 5             0.03             0.07                1.9           0.09
# 7              NaN              NaN                NaN            NaN
# 8              NaN              NaN                NaN            NaN
# 9         1.052517          1.07851           0.981436       1.037039
# 10        1.221139         1.948027           0.702692        1.60103
#
#               ANT                  ARL                 ARM            ASE  \
# 0           ANTAN        ARABIA LIGERO        ARABIA MEDIO          ASENG
# 1     CEPSA ANTAN  CEPSA ARABIA LIGERO  CEPSA ARABIA MEDIO    CEPSA ASENG
# 2   07 marzo 2018   01 septiembre 1997     01 octubre 1990  01 enero 2012
# 3            26.2                32.95               31.06           29.3
# 4          0.8968                 0.86                0.87         0.8795
# 5             0.3                 2.01                 2.5           0.25
# 7             NaN                  NaN                 NaN            NaN
# 8             NaN                  NaN                 NaN            NaN
# 9         0.95933              1.00038            0.988882         0.9782
# 10       0.431805             1.011292             1.04478       0.435602
#
#                     ASG                 AVH            AXN            ATA  \
# 0         AASGARD BLEND        ALVHEIMBLEND           AMNA          ATAPU
# 1   CEPSA AASGARD BLEND  CEPSA ALVHEIMBLEND     CEPSA AMNA    CEPSA ATAPU
# 2     01 noviembre 2017  05 septiembre 2013  01 abril 2004  01 junio 2020
# 3                  49.5                34.9          36.47          0.396
# 4                0.7814                0.85          0.842         0.8886
# 5                  0.18                0.17           0.11          0.394
# 7                   NaN                 NaN            NaN            NaN
# 8                   NaN                 NaN            NaN            NaN
# 9              1.101007             1.01215       1.021766       0.968183
# 10             3.043869            0.925464       0.778803       0.600875
#
#                 AZE                 BAL                  BAP            BAU  \
# 0    Azeri CIC 2020        BASRA LIGERO        BASRAH PESADO          BAUNA
# 1    Azeri CIC 2020  CEPSA BASRA LIGERO  CEPSA BASRAH PESADO    CEPSA BAUNA
# 2   septiembre 2020       30 junio 2008        01 abril 2015  21 enero 2020
# 3             38.77                29.5                  4.2           33.2
# 4            0.8305              0.8785               0.9119         0.8589
# 5              0.15                3.17                  4.2          0.238
# 7               NaN                 NaN                  NaN            NaN
# 8               NaN                 NaN                  NaN            NaN
# 9          1.035915            0.979314             0.943445       1.001662
# 10         1.359715            0.940322             0.804653       1.000507
#
#                   BBB                 BGA                BLA  \
# 0         BRENT BLEND               BREGA          BLACKHAWK
# 1   CEPSA BRENT BLEND         CEPSA BREGA    CEPSA BLACKHAWK
# 2       01 junio 1998  01 septiembre 2018  14 noviembre 2014
# 3                38.9                0.19               52.2
# 4                0.83              0.8139             0.7703
# 5                0.35                0.19               0.03
# 7                 NaN                 NaN                NaN
# 8                 NaN                 NaN                NaN
# 9            1.036539            1.057043           1.116873
# 10           1.537608             1.55587           2.111635
#
#                   BMS                 BOL                 BON  \
# 0         BRYAN MOUND        BONNY LIGERO               BONGA
# 1   CEPSA BRYAN MOUND  CEPSA BONNY LIGERO         CEPSA BONGA
# 2     28 febrero 2018     01 febrero 2012  22 septiembre 2017
# 3                40.7               36.55                27.7
# 4              0.8215               0.842              0.8883
# 5                0.44                0.17                0.25
# 7                 NaN                 NaN                 NaN
# 8                 NaN                 NaN                 NaN
# 9            1.047264            1.021766             0.96851
# 10           1.921817            1.792858            0.665535
#
#                   BRR                BUA            BUZ                   CAE  \
# 0         BRASS RIVER         BU ATTIFEL         BUZIOS        CABINDA EXPORT
# 1   CEPSA BRASS RIVER   CEPSA BU ATTIFEL   CEPSA BUZIOS  CEPSA CABINDA EXPORT
# 2       01 junio 2011  01 diciembre 1996  01 abril 2020        01 agosto 1994
# 3                0.18              42.31           0.28                  32.7
# 4              0.8379              0.814         0.8825                0.8615
# 5                0.18               0.02           0.28                  0.12
# 7                 NaN                NaN            NaN                   NaN
# 8                 NaN                NaN            NaN                   NaN
# 9            1.026766           1.056913       0.974875              0.998639
# 10           1.560803            0.76325       0.749552              0.827112
#
#                   CEB            CEP             CHE            CJB  \
# 0         CEIBA BLEND             EA        CHELEKEN       CJ Blend
# 1   CEPSA CEIBA BLEND       CEPSA EA  CEPSA CHELEKEN       CJ Blend
# 2        01 mayo 2007  08 junio 2015   01 marzo 2012  10 enero 2021
# 3                30.7           0.12            0.08           35.7
# 4              0.8721         0.8801          0.8226         0.8457
# 5                0.46           0.12            0.08            0.1
# 7                 NaN            NaN             NaN            NaN
# 8                 NaN            NaN             NaN            NaN
# 9            0.986501       0.977533        1.045863       1.017296
# 10           0.875745        0.49077        1.180188       1.222746
#
#                   CLA             CLO              CPB                 DAB  \
# 0               CLAIR            Clov        CPC BLEND        DAS BLEND CI
# 1         Cepsa CLAIR      Cepsa Clov  CEPSA CPC BLEND  CEPSA DAS BLEND CI
# 2   01 diciembre 2010  27 agosto 2014    06 julio 2015     01 octubre 2014
# 3                23.6            31.8             45.8               39.72
# 4              0.9121          0.8663           0.7978              0.8264
# 5                0.47            0.26             0.55                1.09
# 7                 NaN             NaN              NaN                 NaN
# 8                 NaN             NaN              NaN                 NaN
# 9            0.943238        0.993105         1.078375            1.041054
# 10           0.475037        0.835976         2.183152            1.451234
#
#                 DAL            DJE                  DSW            DUC  \
# 0             Dalia          DJENO       DOMESTIC SWEET            DUC
# 1   CEPSA DALIA Tfe    CEPSA DJENO  CEPSA DOMESTICSWEET      CEPSA DUC
# 2     01 marzo 2013  30 enero 2018        01 abril 2016  14 enero 2005
# 3              23.3           26.4                 41.1          33.55
# 4            0.9144         0.8957               0.8195         0.8569
# 5              0.44           0.54                  0.4           0.25
# 7               NaN            NaN                  NaN            NaN
# 8               NaN            NaN                  NaN            NaN
# 9          0.940865       0.960508              1.04982          1.004
# 10         0.201315       0.537283             1.935173       1.214105
#
#                     E46                  E44               EAF  \
# 0         Eagle Ford 45        Eagle Ford 44        EAGLE FORD
# 1   CEPSA Eagle Ford 45  CEPSA EAGLE FORD 44  CEPSA EAGLE FORD
# 2         01 abril 2019        27 enero 2020     05 julio 2016
# 3                  0.11                 0.34              55.4
# 4                0.7982                0.806            0.7566
# 5                  0.11                 0.34              0.04
# 7                   NaN                  NaN               NaN
# 8                   NaN                  NaN               NaN
# 9              1.077834             1.067404          1.137097
# 10             1.624461             1.836987          2.863244
#
#                   EBO                EGI            EKO               ENT  \
# 0               EBOME              EGINA        EKOFISK        ENTERPRISE
# 1         CEPSA EBOME        CEPSA EGINA  Cepsa EKOFISK  CEPSA ENTERPRISE
# 2   14 diciembre 2015  06 diciembre 2017  12 enero 2011   01 octubre 2015
# 3               33.23               0.17           38.4              0.05
# 4              0.8382             0.8907         0.8324            0.7689
# 5                0.08               0.17           0.22              0.05
# 7                 NaN                NaN            NaN               NaN
# 8                 NaN                NaN            NaN               NaN
# 9            1.026398             0.9659        1.03355          1.118907
# 10           1.597142           0.278642       1.528303          2.358671
#
#                ERH            ESC               ESH            ESP  \
# 0             ERHA       ESCRAVOS        ES Sharara         ESPOIR
# 1       CEPSA ERHA       ESCRV322  CEPSA Es Sharara   CEPSA ESPOIR
# 2   01 agosto 2018  18 enero 2017     01 enero 2004  09 enero 2018
# 3             34.8           0.17              0.07            0.3
# 4           0.8502         0.8639            0.8103         0.8668
# 5             0.23          0.175              0.07           0.29
# 7              NaN            NaN               NaN            NaN
# 8              NaN            NaN               NaN            NaN
# 9         1.011912       0.995864          1.061739       0.992533
# 10        1.055213       0.937067          1.780356       0.865369
#
#                   ESS                FLG                  FOB  \
# 0            ES SIDER        Flotta Gold        FORTIES BLEND
# 1      CEPSA ES SIDER  CEPSA Flotta Gold  CEPSA FORTIES BLEND
# 2   01 diciembre 1993  01 diciembre 2014    04 noviembre 2011
# 3                36.6               36.4                 38.7
# 4              0.8418             0.8426                0.831
# 5                 0.4               0.66                 0.79
# 7                 NaN                NaN                  NaN
# 8                 NaN                NaN                  NaN
# 9            1.022009           1.021039             1.035291
# 10           1.181756           1.278199             1.679336
#
#                   FOR                   FRL             GIR              GKR  \
# 0            FORCADOS        FORCADOS LIGHT        GIRASSOL        GINA KROG
# 1      CEPSA FORCADOS  CEPSA FORCADOS LIGHT  CEPSA GIRASSOL  CEPSA GINA KROG
# 2   04 noviembre 2013        31 agosto 2016   01 abril 2002    27 junio 2018
# 3                32.6                 40.87           31.57             36.3
# 4               0.862                0.8209          0.8677           0.8429
# 5                0.14                  0.11            0.32             0.31
# 7                 NaN                   NaN             NaN              NaN
# 8                 NaN                   NaN             NaN              NaN
# 9            0.998059              1.048029        0.991503         1.020675
# 10           0.964733               2.12159        0.792866         1.535451
#
#                GDG                 GLT                GRA            GUA  \
# 0         GINDUNGO        GOLIAT BLEND        GRANE BLEND        GUAFITA
# 1   CEPSA GINDUNGO  CEPSA GOLIAT BLEND  CEPSA GRANE BLEND  CEPSA GUAFITA
# 2    13 abril 2018       06 marzo 2015      01 marzo 2019  17 marzo 2007
# 3               32                40.3               0.59           26.9
# 4            0.865              0.8231             0.8814         0.8928
# 5             0.58                0.14               0.59           0.87
# 7              NaN                 NaN                NaN            NaN
# 8              NaN                 NaN                NaN            NaN
# 9         0.994598            1.045228           0.976092       0.963628
# 10        0.969065            1.576642           0.826263       0.504002
#
#                GUL             HIB            IRA                IRL  \
# 0         Gullfaks        HIBERNIA        IRACEMA        IRAN LIGERO
# 1   CEPSA GULLFAKS  CEPSA HIBERNIA  Cepsa Iracema  CEPSA IRAN LIGERO
# 2   15 agosto 2014   01 julio 2017   29 mayo 2020      24 junio 2016
# 3             0.22            0.53           0.28               33.4
# 4           0.8291          0.8554         0.8613             0.8579
# 5             0.22            0.53           0.28               1.56
# 7              NaN             NaN            NaN                NaN
# 8              NaN             NaN            NaN                NaN
# 9         1.037664         1.00576       0.998871           1.002829
# 10        1.509414         1.05167       0.980548           1.206814
#
#                   IRP             IST                JON  \
# 0         IRAN PESADO        ISTMO 32        JONES CREEK
# 1   CEPSA IRAN PESADO  CEPSA ISTMO 32  CEPSA JONES CREEK
# 2       21 junio 2016    01 mayo 2014  13 noviembre 2018
# 3                2.02           32.58               29.8
# 4              0.8788          0.8624             0.8768
# 5                2.02            1.58               0.18
# 7                 NaN             NaN                NaN
# 8                 NaN             NaN                NaN
# 9             0.97898        0.997597           0.981213
# 10           0.959205        1.073096           0.674103
#
#                      JSV                  JUB                   KIB  \
# 0         Johan Sverdrup        Jubilee Blend        Kissanje Blend
# 1   CEPSA JOHAN SVERDRUP  CEPSA Jubilee Blend  Cepsa Kissanje Blend
# 2           febrero 2019       27 agosto 2019         01 julio 2019
# 3                     28                37.41                  0.37
# 4                 0.8867               0.8373                0.8785
# 5                    0.8                  0.3                  0.37
# 7                    NaN                  NaN                   NaN
# 8                    NaN                  NaN                   NaN
# 9               0.970257             1.027502              0.979314
# 10              0.730913             1.433982              0.770211
#
#                    KIR                KOL                KOM  \
# 0                 EBCO               KOLE        KOLE MARINE
# 1           CEPSA EBCO         CEPSA KOLE  CEPSA KOLE MARINE
# 2   27 septiembre 2016  01 diciembre 2013      11 junio 2018
# 3                 30.3               28.5               0.55
# 4               0.8739             0.8837             0.8824
# 5                 2.73               0.42               0.55
# 7                  NaN                NaN                NaN
# 8                  NaN                NaN                NaN
# 9             0.984469           0.973551           0.974986
# 10            1.059387           0.638796           0.766295
#
#                     KUE                 LAE                    LIV  \
# 0         KUWAIT EXPORT        LAVAN EXPORT        LIVERPOOL BLEND
# 1   CEPSA KUWAIT EXPORT  CEPSA LAVAN EXPORT  CEPSA LIVERPOOL BLEND
# 2          11 mayo 2008      16 agosto 2008                      0
# 3                  2.74                35.5               0.313666
# 4                0.8736              0.8472                 0.8088
# 5                  2.74                 1.6                   0.36
# 7                   NaN                 NaN                    NaN
# 8                   NaN                 NaN                    NaN
# 9              0.984807            1.015495               1.063708
# 10             0.957516            1.284942               1.642076
#
#               LOK                 LUB            LUL            MAN  \
# 0          LOKELE        LUCINA BLEND           LULA         MANDJI
# 1    CEPSA LOKELE  CEPSA LUCINA BLEND     CEPSA LULA   CEPSA MANDJI
# 2   17 julio 2019   01 diciembre 2006  01 junio 2012  01 junio 1995
# 3            0.33                  35           30.5           29.6
# 4          0.9076                0.85         0.8731          0.878
# 5            0.33                0.07           0.35           1.06
# 7             NaN                 NaN            NaN            NaN
# 8             NaN                 NaN            NaN            NaN
# 9        0.947915             1.01215       0.985371       0.979872
# 10       0.532672            0.925838       0.787426       0.749778
#
#                    MAR            MAY                 MDN            MRO  \
# 0                 MARS           MAYA            MEDANITO           MERO
# 1           CEPSA MARS     CEPSA MAYA      CEPSA MEDANITO     CEPSA MERO
# 2   10 septiembre 2012  01 julio 1992  13 septiembre 2018  01 junio 2018
# 3                 28.8           21.6                40.2           28.5
# 4               0.8822          0.924              0.8238         0.8836
# 5                  1.8           3.34                0.33           0.33
# 7                  NaN            NaN                 NaN            NaN
# 8                  NaN            NaN                 NaN            NaN
# 9             0.975207        0.93109             1.04434       0.973661
# 10            0.936468       0.646546            1.838503       0.627119
#
#                 ME3                MEL                    MUR            NEM  \
# 0           MESA 30           MELLITAH        Murban Exp. Bld          NEMBA
# 1     CEPSA MESA 30     CEPSA MELLITAH  CEPSA Murban Exp. Bld    CEPSA NEMBA
# 2   01 octubre 1998  29 noviembre 2017        01 octubre 2009  01 enero 2013
# 3                30               43.7                   39.9           37.9
# 4            0.8765             0.8072                 0.8252          0.837
# 5              1.08               0.11                   0.81           0.27
# 7               NaN                NaN                    NaN            NaN
# 8               NaN                NaN                    NaN            NaN
# 9          0.981548           1.065817               1.042568        1.02787
# 10          0.80708           2.065184               1.354943       1.516882
#
#                NKO              NOD              OBE                 OGU  \
# 0           Nkossa           BAKKEN        OKWUIBOME            OGUENDJO
# 1     Cepsa Nkossa     CEPSA BAKKEN  CEPSA OKWUIBOME  CEPSA OGUENDJO (c)
# 2   25 agosto 2017  20 febrero 2018  01 febrero 2016       01 abril 2019
# 3             0.04             43.4              0.1                35.6
# 4           0.8133           0.8086           0.8335              0.8462
# 5             0.04              0.1              0.1                0.75
# 7              NaN              NaN              NaN                 NaN
# 8              NaN              NaN              NaN                 NaN
# 9         1.057823         1.063971         1.032186            1.016695
# 10           1.492         1.906384         1.616901            1.245821
#
#               OKO                OKR            OKW              OLE  \
# 0           OKONO        OKORO LIGHT         OKWORI        OLOMBENDO
# 1     CEPSA OKONO  CEPSA OKORO LIGHT   CEPSA OKWORI  CEPSA OLOMBENDO
# 2   09 abril 2011    06 febrero 2018  01 junio 2005    01 marzo 2011
# 3            40.5              36.43          36.81             35.2
# 4          0.8223             0.8421         0.8407           0.8486
# 5            0.06                0.1           0.11             0.12
# 7             NaN                NaN            NaN              NaN
# 8             NaN                NaN            NaN              NaN
# 9        1.046245           1.021645       1.023346         1.013819
# 10       1.656336           1.196321       0.938668         1.047043
#
#                   OME            OSE              OTA                 PAZ  \
# 0         OMAN EXPORT        OSEBERG         OTAKIKPO             Pazflor
# 1   CEPSA OMAN EXPORT  CEPSA OSEBERG   CEPSA OTAKIKPO       Cepsa PAzflor
# 2       01 marzo 2017   20 mayo 2016  01 octubre 2017  16 septiembre 2011
# 3                30.5           39.6             41.2               25.67
# 4              0.8731         0.8268           0.8191              0.8998
# 5                1.52            0.2             0.06                0.39
# 7                 NaN            NaN              NaN                 NaN
# 8                 NaN            NaN              NaN                 NaN
# 9            0.985371       1.040551         1.050332            0.956132
# 10           0.832554       1.659184         1.585546            0.462367
#
#                   PEN              PIE             PLU              QAR  \
# 0          PENNINGTON           PIERCE        PLUTONIO            QARUN
# 1    CEPSA PENNINGTON     CEPSA PIERCE  CEPSA PLUTONIO  CEPSA QARUN NEW
# 2   11 noviembre 2016  12 febrero 2018   01 julio 2017    26 junio 2019
# 3                37.6            40.17            0.32         0.361059
# 4              0.8365            0.824          0.8682           0.8548
# 5                 0.1             0.16            0.32             0.37
# 7                 NaN              NaN             NaN              NaN
# 8                 NaN              NaN             NaN              NaN
# 9            1.028484         1.044086        0.990932         1.006466
# 10           1.481659         1.575599        0.980561         0.826994
#
#                QUI                RAB                         REB  \
# 0         QUA IBOE         RABI BLEND        RUSSIAN EXPORT BLEND
# 1   CEPSA QUA IBOE   CEPSA RABI BLEND  CEPSA RUSSIAN EXPORT BLEND
# 2    01 enero 2018  01 diciembre 2003               01 enero 2002
# 3             37.6               33.4                        31.8
# 4           0.8365              0.858                      0.8662
# 5              0.1               0.07                        1.32
# 7              NaN                NaN                         NaN
# 8              NaN                NaN                         NaN
# 9         1.028484           1.002712                     0.99322
# 10        1.421312           0.469147                    0.988339
#
#                  SA1                  SAB            SAT                 SCH  \
# 0         SAXI BLEND        SAHARAN BLEND        SATURNO        Schiehallion
# 1   CEPSA SAXI BLEND  CEPSA SAHARAN BLEND  CEPSA SATURNO  CEPSA SCHIEHALLION
# 2       01 mayo 2008           marzo 2021  01 marzo 2013   21 noviembre 2013
# 3               32.7                45.84           25.6                0.46
# 4             0.8611               0.7972         0.9001              0.9025
# 5                0.3               0.0775           0.83                0.46
# 7                NaN                  NaN            NaN                 NaN
# 8                NaN                  NaN            NaN                 NaN
# 9           0.999103             1.079186       0.955813            0.953271
# 10          0.962594             2.029027       0.691126            0.200437
#
#                      SIL            SIR            SKF             SAP  \
# 0         SIBERIAN LIGHT          SIRRI        SANKOFA        SAPINHOA
# 1   CEPSA SIBERIAN LIGHT    CEPSA SIRRI  CEPSA SANKOFA  CEPSA SAPINHOA
# 2     01 septiembre 1995  07 marzo 2017  14 julio 2017      enero 2013
# 3                   35.1             33           28.9            29.8
# 4                 0.8486         0.8599         0.8816          0.8771
# 5                   0.57           1.83            0.3            0.37
# 7                    NaN            NaN            NaN             NaN
# 8                    NaN            NaN            NaN             NaN
# 9               1.013819       1.000497        0.97587        0.980877
# 10              1.105166       1.184897       0.631643        0.808162
#
#                   SMS            SNG            SOR              STA  \
# 0               SARIR        SONGKLA       SOROOSH         STATFJORD
# 1         CEPSA SARIR  CEPSA SONGKLA  CEPSA SOROOSH  CEPSA STATFJORD
# 2   17 noviembre 2015              0  04 junio 2002    19 abril 2010
# 3                37.4              0          19.72             39.5
# 4              0.8373          0.887         0.9352            0.827
# 5                0.15              0           3.15             0.22
# 7                 NaN            NaN            NaN              NaN
# 8                 NaN            NaN            NaN              NaN
# 9            1.027502       0.969929       0.919939         1.040299
# 10           1.125294       0.111178       0.507565           1.5589
#
#                 TEN              SUR               TER                    TIE  \
# 0         TEN BLEND           SURURU        TERRA NOVA        TI Epic/GrayOak
# 1   CEPSA TEN BLEND     CEPSA SURURU  CEPSA TERRA NOVA  CEPSA TI Epic/GrayOak
# 2     01 enero 2017  01 octubre 2019     01 junio 2014        21 febrero 2017
# 3              33.8             0.32              34.2                   42.6
# 4            0.8554           0.8845             0.854                 0.8124
# 5              0.43             0.32              0.52                  0.094
# 7               NaN              NaN               NaN                    NaN
# 8               NaN              NaN               NaN                    NaN
# 9           1.00576         0.972671          1.007409               1.058995
# 10         1.124055         0.676061          1.080612               1.718754
#
#                  TIP                TRO                URL               USB  \
# 0         TI Permian        TROLL BLEND        URAL LIGERO        USAN Blend
# 1   CEPSA TI Permian  CEPSA TROLL BLEND  CEPSA URAL LIGERO  CEPSA USAN BLEND
# 2    21 febrero 2017      06 abril 2018      01 marzo 1988      01 mayo 2019
# 3               43.1               35.4                 34                28
# 4             0.8101             0.8472             0.8545            0.8865
# 5              0.176               0.18                1.3               0.3
# 7                NaN                NaN                NaN               NaN
# 8                NaN                NaN                NaN               NaN
# 9           1.062001           1.015495           1.006819          0.970476
# 10          1.716777           1.508877           1.153614          0.714305
#
#                          UZE                VAR             VAS  \
# 0         Upper Zakum Exp Bl           VARANDEY        VASCONIA
# 1   CEPSA UPPER ZAKUM EXP BL     CEPSA VARANDEY  CEPSA VASCONIA
# 2              01 enero 2009  01 noviembre 2012   01 enero 2014
# 3                       1.89               35.1           28.81
# 4                     0.8542             0.8492          0.8827
# 5                       1.89               0.61            0.78
# 7                        NaN                NaN             NaN
# 8                        NaN                NaN             NaN
# 9                   1.007173           1.013103        0.974654
# 10                    1.1798           0.855844        1.131544
#
#                               WCS                   WED                 WHC  \
# 0          Western Canad'n Select        WESTERN DESERT        WHITE CLIFFS
# 1   CEPSA Western Canadian Select  CEPSA WESTERN DESERT  CEPSA WHITE CLIFFS
# 2               01 diciembre 2011         01 enero 2016   02 noviembre 2015
# 3                             3.4                  41.1                49.4
# 4                          0.9298                0.8194              0.7819
# 5                             3.4                  0.32                0.06
# 7                             NaN                   NaN                 NaN
# 8                             NaN                   NaN                 NaN
# 9                        0.925282              1.049948            1.100303
# 10                       0.829631              1.902151            2.373182
#
#                  WHR                      WTC                    WML  \
# 0         WHITE ROSE        WEST TEXAS CACTUS  West Texas Light 46.3
# 1   CEPSA WHITE ROSE  CEPSA WEST TEXAS CACTUS               WTXLT463
# 2      01 enero 2014          21 febrero 2017        30 octubre 2018
# 3               31.7                     43.1               0.058846
# 4              0.867                   0.8101                 0.7955
# 5               0.26                     0.14                   0.06
# 7                NaN                      NaN                    NaN
# 8                NaN                      NaN                    NaN
# 9           0.992304                 1.062001               1.081492
# 10          0.863287                 1.938545               1.932392
#
#                 WTL            YOH                 ZAB                 ZAE  \
# 0         WTI LIGHT           YOHO        ZAFIRO BLEND        ZAIRE EXPORT
# 1   CEPSA WTI LIGHT     CEPSA YOHO  CEPSA ZAFIRO BLEND  CEPSA ZAIRE EXPORT
# 2     31 enero 2019  01 enero 2018      01 agosto 2008       01 junio 1994
# 3              48.6           40.5                30.6                31.4
# 4            0.7854         0.8225              0.8725              0.8686
# 5              0.03           0.06                0.27                0.12
# 7               NaN            NaN                 NaN                 NaN
# 8               NaN            NaN                 NaN                 NaN
# 9            1.0954       1.045991            0.986048            0.990476
# 10         2.285555       1.686473            0.979827            0.729568
#
#                   ZAR             ZUE
# 0          ZARZAITINE        ZUEITINA
# 1    CEPSA ZARZAITINE  CEPSA ZUEITINA
# 2   01 noviembre 2019               0
# 3               43.97            41.3
# 4              0.8057          0.8185
# 5                0.08            0.28
# 7                 NaN             NaN
# 8                 NaN             NaN
# 9            1.067801        1.051102
# 10           1.763306        1.436962
# ==============================

# %% [markdown]
# # Cargar Raspacrudos

# %%
def cargar_raspacrudos(excel, hoja):
 
    df_raspa = pd.read_excel(excel, sheet_name = hoja, header = 1)

    for col in list(df_raspa.columns):
        if df_raspa[col].notnull().sum() == 0:
            df_raspa.drop([col], axis=1, inplace=True)

    df_raspa["Fecha 1"] = pd.to_datetime(df_raspa["Fecha Desc."], format='%Y-%m-%d %H:%M:%S', errors = "coerce")
    df_raspa["Fecha 2"] = pd.to_datetime(df_raspa["Fecha Desc."], format='%d/%m/%Y', errors = "coerce") 
    df_raspa["Fecha Desc."] = df_raspa["Fecha 1"].combine_first(df_raspa["Fecha 2"])
    df_raspa.drop(['Fecha 1', 'Fecha 2'], axis = 1, inplace = True)
        
    print("Cargado df raspa:")
    print(df_raspa.shape)
    display(df_raspa.head(3))
    print("==============================")
    
    return df_raspa

# %%
excel_raspa = r"C:\Users\JESCOBARO\Desktop\CDX_PIMS\Raspa Crudos PILOTAGE.xlsm"
hoja_excel = "CRUDOS"

df_raspa = cargar_raspacrudos(excel_raspa, hoja_excel)
# Out:
# Cargado df raspa:
# (2298, 61)
#   Código Fecha Pedido Código Fecha Fecha pedida Fecha Desc. Refinería  \
# 0           40701RGSR    40695RGSR   2011-06-07  2011-06-01      RGSR
# 1            40701RLR     40695RLR   2011-06-07  2011-06-01       RLR
# 2            40701RLR     40696RLR   2011-06-07  2011-06-02       RLR
#
#                   Crudo Cantidad Observaciones MES ABASTEC BARCO ETA   CD  \
# 0           Kole Marine   110978  Tenerife sp.         NaN   NaN NaT  NaN
# 1  RUSSIAN EXPORT BLEND   129374          Reef         NaN   NaN NaT  NaN
# 2              Qua Iboe   122072    Toledo sp.         NaN   NaN NaT  NaN
#
#   FECHA DESCARGA CRUDO2  CANTIDAD (t) Estado  API  %S FAMILIA  \
# 0            NaT    NaN           NaN    NaN  NaN NaN     NaN
# 1            NaT    NaN           NaN    NaN  NaN NaN     NaN
# 2            NaT    NaN           NaN    NaN  NaN NaN     NaN
#
#   FÓRMULA COMPRA \n(PROGRAMA)  ESTIMACIÓN FLETE \n(PROGRAMA)  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
#
#   FÓRMULA COMPRA \n(BUDGET)  ESTIMACIÓN FLETE \n(BUDGET)  D FÓRMULA COMPRA  \
# 0                       NaN                          NaN               NaN
# 1                       NaN                          NaN               NaN
# 2                       NaN                          NaN               NaN
#
#    D ESTIMACIÓN FLETE Cierre FECHA CARGA Comentarios Otros comentarios  \
# 0                 NaN    NaN         NaT         NaN               NaN
# 1                 NaN    NaN         NaT         NaN               NaN
# 2                 NaN    NaN         NaT         NaN               NaN
#
#    DEAL STRATEGY FECHA COMPRA LCi LCf ETBallegro ETS LAi LAf ETAallegro  \
# 0            NaN          NaN NaT NaT   00:00:00 NaT NaT NaT   00:00:00
# 1            NaN          NaN NaT NaT   00:00:00 NaT NaT NaT   00:00:00
# 2            NaN          NaN NaT NaT   00:00:00 NaT NaT NaT   00:00:00
#
#   PRICING Rev PIMS  Inc RGSR  Inc RLR Tomahawk vigente FLETE REAL  \
# 0     NaN      NaN       NaN      NaN              NaN        NaN
# 1     NaN      NaN       NaN      NaN              NaN        NaN
# 2     NaN      NaN       NaN      NaN              NaN        NaN
#
#    ESTIMACIÓN COMPRA\n(PIMS)  ESTIMACIÓN FLETE\n(PIMS)  API*  %S* en camino  \
# 0                        NaN                       NaN   NaN  NaN       NaN
# 1                        NaN                       NaN   NaN  NaN       NaN
# 2                        NaN                       NaN   NaN  NaN       NaN
#
#    CARGA  DESCARGA DEMORAS  DEMORAS ($/día) Operador  DESVÍO PEDIDO  \
# 0    NaN       NaN     NaN              NaN      NaN       -40701.0
# 1    NaN       NaN     NaN              NaN      NaN       -40701.0
# 2    NaN       NaN     NaN              NaN      NaN       -40701.0
#
#    DESVÍO ALLEGRO  DESVÍO DESCARGA      ETB-I  ETS-ETB  ETA-ETS  ETD-ETA
# 0             0.0           -40701 1778-07-29      0.0      0.0      0.0
# 1             0.0           -40701 1778-07-29      0.0      0.0      0.0
# 2             0.0           -40701 1778-07-29      0.0      0.0      0.0
# ==============================

# %%
df_raspa = df_raspa.replace({'Crudo': "Arabia"}, "Arabia Ligero")
df_raspa = df_raspa.replace({'Crudo': "Arabia ligero"}, "Arabia Ligero")
df_raspa = df_raspa.replace({'Crudo': "QUA IBOE"}, "Qua iboe")

# %%
df_raspa["Month_order"] = pd.to_datetime(df_raspa["Fecha Desc."], format= '%b-%y')
df_aux = df_raspa[df_raspa["Month_order"] >= "2020-10-01"]
df_aux[(df_aux["Refinería"] == "RGSR") & (df_aux["Crudo"] == "Amenam Blend")]
# Out:
#      Código Fecha Pedido Código Fecha Fecha pedida Fecha Desc. Refinería  \
# 2065           44121RGSR    44122RGSR   2020-10-17  2020-10-18      RGSR
# 2072           44141RGSR    44141RGSR   2020-11-06  2020-11-06      RGSR
# 2122           44252RGSR    44250RGSR   2021-02-25  2021-02-23      RGSR
# 2180           44354RGSR    44356RGSR   2021-06-07  2021-06-09      RGSR
# 2211            44415RLR    44401RGSR   2021-08-07  2021-07-24      RGSR
#
#              Crudo    Cantidad  \
# 2065  Amenam Blend      130000
# 2072  Amenam Blend      130000
# 2122  Amenam Blend      124285
# 2180  Amenam Blend  124657.854
# 2211  Amenam Blend      125129
#
#                                           Observaciones MES ABASTEC  \
# 2065                                                NaN         NaN
# 2072                                                NaN         NaN
# 2122  Se cierra con una ventana de descarga 29-03/Ma...     febrero
# 2180                                                NaN       junio
# 2211                                    Destilable solo       julio
#
#             BARCO                 ETA     CD FECHA DESCARGA        CRUDO2  \
# 2065          NaN                 NaT    NaN            NaT           NaN
# 2072          NaN                 NaT    NaN            NaT           NaN
# 2122  FRONT SIENA 2021-02-01 00:00:00  24-26     2021-02-23  AMENAM BLEND
# 2180   FRONT THOR 2021-06-05 00:00:00    NaN     2021-06-09  AMENAM BLEND
# 2211   FRONT ODIN 2021-07-24 04:00:00    NaN     2021-07-24  AMENAM BLEND
#
#       CANTIDAD (t) Estado    API    %S          FAMILIA  \
# 2065           NaN    NaN    NaN   NaN              NaN
# 2072           NaN    NaN    NaN   NaN              NaN
# 2122    124285.000    (D)  38.98  0.09  Light Sweet IMO
# 2180    124657.854    (D)  38.98  0.09  Light Sweet IMO
# 2211    125129.000    (C)  38.98  0.09  Light Sweet IMO
#
#      FÓRMULA COMPRA \n(PROGRAMA)  ESTIMACIÓN FLETE \n(PROGRAMA)  \
# 2065                         NaN                            NaN
# 2072                         NaN                            NaN
# 2122                   BR + 0,81                            NaN
# 2180                   BR - 0,99                           0.82
# 2211                      BR + 0                            NaN
#
#      FÓRMULA COMPRA \n(BUDGET)  ESTIMACIÓN FLETE \n(BUDGET)  D FÓRMULA COMPRA  \
# 2065                       NaN                          NaN               NaN
# 2072                       NaN                          NaN               NaN
# 2122                   BR +0,6                         0.98               NaN
# 2180                   BR +0,6                         0.98             -1.59
# 2211                   BR +0,6                          NaN               NaN
#
#       D ESTIMACIÓN FLETE    Cierre FECHA CARGA  \
# 2065                 NaN       NaN         NaT
# 2072                 NaN       NaN         NaT
# 2122               -0.98  Cerrado.         NaT
# 2180               -0.16  Cerrado.  2021-05-22
# 2211                 NaN  Cerrado.  2021-07-10
#
#                                             Comentarios Otros comentarios  \
# 2065                                                NaN               NaN
# 2072                                                NaN               NaN
# 2122                                          Fondeado.               NaN
# 2180                                                NaN               NaN
# 2211  Intercambiado a RLR por el Qua de Agosto por r...               NaN
#
#       DEAL STRATEGY         FECHA COMPRA        LCi        LCf  \
# 2065            NaN                  NaN        NaT        NaT
# 2072            NaN                  NaN        NaT        NaT
# 2122            NaN                  NaN        NaT        NaT
# 2180       103328.0  2021-04-29 00:00:00 2021-05-22 2021-05-23
# 2211       103501.0  2021-06-15 00:00:00 2021-07-08 2021-07-09
#
#                ETBallegro                 ETS        LAi        LAf  \
# 2065             00:00:00                 NaT        NaT        NaT
# 2072             00:00:00                 NaT        NaT        NaT
# 2122             00:00:00 1900-01-01 12:00:00        NaT        NaT
# 2180  2021-05-22 12:00:00 2021-05-23 12:00:00 2021-06-06 2021-06-07
# 2211  2021-07-08 12:00:00 2021-07-08 00:00:00 2021-08-01 2021-08-02
#
#                ETAallegro                    PRICING Rev PIMS  Inc RGSR  \
# 2065             00:00:00        2020-10-01 00:00:00      NaN       NaN
# 2072             00:00:00        2020-10-01 00:00:00      NaN       NaN
# 2122             00:00:00                        NaN  FEB21_5  0.009139
# 2180  2021-06-06 12:00:00                15 -21 Mayo  JUN21_4 -0.606316
# 2211  2021-08-01 12:00:00  5 Bus days after BOL DATE  JUL21_2 -0.523512
#
#        Inc RLR Tomahawk vigente FLETE REAL  ESTIMACIÓN COMPRA\n(PIMS)  \
# 2065       NaN              NaN        NaN                        NaN
# 2072       NaN              NaN        NaN                        NaN
# 2122  0.009139              NaN        NaN                        NaN
# 2180 -0.606316              NaN        NaN                        NaN
# 2211 -0.523512              NaN       CFR                         NaN
#
#       ESTIMACIÓN FLETE\n(PIMS)          API*          %S* en camino  \
# 2065                       NaN           NaN          NaN       NaN
# 2072                       NaN           NaN          NaN       NaN
# 2122                       NaN  4.844629e+06  11185.65000         ?
# 2180                       NaN  4.859163e+06  11219.20686     LLEGÓ
# 2211                       NaN  4.877528e+06  11261.61000     LLEGÓ
#
#              CARGA   DESCARGA DEMORAS  DEMORAS ($/día)        Operador  \
# 2065           NaN        NaN     NaN              NaN             NaN
# 2072           NaN        NaN     NaN              NaN             NaN
# 2122  44228.000000  22.000000     NaN              NaN             NaN
# 2180     14.000000   4.000000     NaN              NaN  César González
# 2211     14.166667  -0.166667     NaN          22500.0             NaN
#
#       DESVÍO PEDIDO  DESVÍO ALLEGRO  DESVÍO DESCARGA      ETB-I  ETS-ETB  \
# 2065       -44121.0        0.000000           -44121 1778-07-29      0.0
# 2072       -44141.0        0.000000           -44141 1778-07-29      0.0
# 2122       -44252.0    44228.000000               -2 1778-07-29      1.5
# 2180           -0.5       -1.500000                2 1899-12-20      1.5
# 2211           -5.5       -8.333333              -14 1900-02-08     -2.0
#
#            ETA-ETS    ETD-ETA Month_order
# 2065      0.000000   0.000000  2020-10-18
# 2072      0.000000   0.000000  2020-11-06
# 2122  44226.500000  22.000000  2021-02-23
# 2180     12.500000   4.000000  2021-06-09
# 2211     16.166667  -0.166667  2021-07-24

# %%
df_aux = df_raspa[(df_raspa["Month_order"] >= "2020-10-01") & (df_raspa["Month_order"] <= "2021-09-01")]
df_aux = df_aux[df_aux["Refinería"] == "RGSR"]
pd.DataFrame(df_aux.groupby(["Refinería", "Crudo"])["Cantidad"].sum()).sort_values(by="Cantidad", ascending = False)
# Out:
#                                         Cantidad
# Refinería Crudo
# RGSR      Arabia Ligero             1.606029e+06
#           Escravos                  1.038271e+06
#           Forcados                  6.579456e+05
#           Amenam Blend              6.340719e+05
#           Buzios                    5.418731e+05
#           Bonga                     4.026789e+05
#           Pennington                3.908989e+05
#           Akpo                      3.885396e+05
#           Qua iboe                  3.715893e+05
#           Saharan Blend             3.576334e+05
#           EBCO                      3.458316e+05
#           Azeri                     2.598975e+05
#           Agbami                    2.424250e+05
#           Brega                     2.406571e+05
#           Okoro light               2.203217e+05
#           Lokele                    1.895406e+05
#           WTI Light                 1.816670e+05
#           CJ Blend                  1.758927e+05
#           Mezcla de Crudo Saldanha  1.406892e+05
#           Jones Creek               1.360970e+05
#           Troll Blend               1.347909e+05
#           Erha                      1.277480e+05
#           Egina                     1.269889e+05
#           Yoho                      1.236917e+05
#           WTL                       9.439100e+04
#           TI CACTUS                 9.091321e+04
#           West Texas Cactus         9.020619e+04
#           Okwori                    8.688562e+04
#           Mellitah                  7.704358e+04
#           ATAPU                     7.079429e+04
#           SURURU                    6.713264e+04
#           Otakikpo                  6.375207e+04
#           TI Epic/GrayOak           6.356228e+04
#           OKONO                     3.263700e+04

# %% [markdown]
# # Dendogram Assay CD1

# %%
df_assays_cd1.head(3)
# Out:
#   ROWNAMES        TEXT  !*? !Type !Prop !Lookup !Stream !Sheet !Lookup.1  \
# 0        *        Name  NaN     1   NaN     NaN     NaN    NaN       NaN
# 1        *   Reference  NaN     2   NaN     NaN     NaN    NaN       NaN
# 2        *  Assay Date  NaN     6   NaN     NaN     NaN    NaN       NaN
#
#                   ARI                  ASG            ABO            AGB  \
# 0  Atm. Res. Imported        AASGARD BLEND            ABO         AGBAMI
# 1                      CEPSA AASGARD BLEND      CEPSA ABO   CEPSA AGBAMI
# 2                        01 noviembre 2017  01 enero 2020  27 junio 2014
#
#               AJE              AKP                ALJ                 AVH  \
# 0             AJE             AKPO            AL JURF        ALVHEIMBLEND
# 1       CEPSA AJE       CEPSA AKPO      CEPSA AL JURF  CEPSA ALVHEIMBLEND
# 2  19 agosto 2016  09 febrero 2015  01 diciembre 2003  05 septiembre 2013
#
#              AMB            AXN            ANT                  ARL  \
# 0   AMENAM BLEND           AMNA          ANTAN        ARABIA LIGERO
# 1   CEPSA AMENAM     CEPSA AMNA    CEPSA ANTAN  CEPSA ARABIA LIGERO
# 2  01 abril 2004  01 abril 2004  07 marzo 2018   01 septiembre 1997
#
#                   ARM            ASE            ATA              AZE  \
# 0        ARABIA MEDIO          ASENG          ATAPU   Azeri CIC 2020
# 1  CEPSA ARABIA MEDIO    CEPSA ASENG    CEPSA ATAPU   Azeri CIC 2020
# 2     01 octubre 1990  01 enero 2012  01 junio 2020  septiembre 2020
#
#                NOD                 BAL                  BAP            BAU  \
# 0           BAKKEN        BASRA LIGERO        BASRAH PESADO          BAUNA
# 1     CEPSA BAKKEN  CEPSA BASRA LIGERO  CEPSA BASRAH PESADO    CEPSA BAUNA
# 2  20 febrero 2018       30 junio 2008        01 abril 2015  21 enero 2020
#
#                  BLA                 BON                 BOL  \
# 0          BLACKHAWK               BONGA        BONNY LIGERO
# 1    CEPSA BLACKHAWK         CEPSA BONGA  CEPSA BONNY LIGERO
# 2  14 noviembre 2014  22 septiembre 2017     01 febrero 2012
#
#                  BRR                 BGA                BBB  \
# 0        BRASS RIVER               BREGA        BRENT BLEND
# 1  CEPSA BRASS RIVER         CEPSA BREGA  CEPSA BRENT BLEND
# 2      01 junio 2011  01 septiembre 2018      01 junio 1998
#
#                  BMS                BUA            BUZ                   CAE  \
# 0        BRYAN MOUND         BU ATTIFEL         BUZIOS        CABINDA EXPORT
# 1  CEPSA BRYAN MOUND   CEPSA BU ATTIFEL   CEPSA BUZIOS  CEPSA CABINDA EXPORT
# 2    28 febrero 2018  01 diciembre 1996  01 abril 2020        01 agosto 1994
#
#                  CEB             CHE            CJB                CLA  \
# 0        CEIBA BLEND        CHELEKEN       CJ Blend              CLAIR
# 1  CEPSA CEIBA BLEND  CEPSA CHELEKEN       CJ Blend        Cepsa CLAIR
# 2       01 mayo 2007   01 marzo 2012  10 enero 2021  01 diciembre 2010
#
#               CLO              CPB              DAL                 DAB  \
# 0            Clov        CPC BLEND            Dalia        DAS BLEND CI
# 1      Cepsa Clov  CEPSA CPC BLEND  CEPSA DALIA Tfe  CEPSA DAS BLEND CI
# 2  27 agosto 2014    06 julio 2015    01 marzo 2013     01 octubre 2014
#
#              DJE                  DSW            DUC            CEP  \
# 0          DJENO       DOMESTIC SWEET            DUC             EA
# 1    CEPSA DJENO  CEPSA DOMESTICSWEET      CEPSA DUC       CEPSA EA
# 2  30 enero 2018        01 abril 2016  14 enero 2005  08 junio 2015
#
#                 EAF                  E44                  E46  \
# 0        EAGLE FORD        Eagle Ford 44        Eagle Ford 45
# 1  CEPSA EAGLE FORD  CEPSA EAGLE FORD 44  CEPSA Eagle Ford 45
# 2     05 julio 2016        27 enero 2020        01 abril 2019
#
#                   KIR                EBO                EGI            EKO  \
# 0                EBCO              EBOME              EGINA        EKOFISK
# 1          CEPSA EBCO        CEPSA EBOME        CEPSA EGINA  Cepsa EKOFISK
# 2  27 septiembre 2016  14 diciembre 2015  06 diciembre 2017  12 enero 2011
#
#                 ENT             ERH               ESH                ESS  \
# 0        ENTERPRISE            ERHA        ES Sharara           ES SIDER
# 1  CEPSA ENTERPRISE      CEPSA ERHA  CEPSA Es Sharara     CEPSA ES SIDER
# 2   01 octubre 2015  01 agosto 2018     01 enero 2004  01 diciembre 1993
#
#              ESC            ESP                FLG                FOR  \
# 0       ESCRAVOS         ESPOIR        Flotta Gold           FORCADOS
# 1       ESCRV322   CEPSA ESPOIR  CEPSA Flotta Gold     CEPSA FORCADOS
# 2  18 enero 2017  09 enero 2018  01 diciembre 2014  04 noviembre 2013
#
#                     FRL                  FOB              GKR             GDG  \
# 0        FORCADOS LIGHT        FORTIES BLEND        GINA KROG        GINDUNGO
# 1  CEPSA FORCADOS LIGHT  CEPSA FORTIES BLEND  CEPSA GINA KROG  CEPSA GINDUNGO
# 2        31 agosto 2016    04 noviembre 2011    27 junio 2018   13 abril 2018
#
#               GIR                 GLT                GRA            GUA  \
# 0        GIRASSOL        GOLIAT BLEND        GRANE BLEND        GUAFITA
# 1  CEPSA GIRASSOL  CEPSA GOLIAT BLEND  CEPSA GRANE BLEND  CEPSA GUAFITA
# 2   01 abril 2002       06 marzo 2015      01 marzo 2019  17 marzo 2007
#
#               GUL             HIB            IRA                IRL  \
# 0        Gullfaks        HIBERNIA        IRACEMA        IRAN LIGERO
# 1  CEPSA GULLFAKS  CEPSA HIBERNIA  Cepsa Iracema  CEPSA IRAN LIGERO
# 2  15 agosto 2014   01 julio 2017   29 mayo 2020      24 junio 2016
#
#                  IRP             IST                   JSV                JON  \
# 0        IRAN PESADO        ISTMO 32        Johan Sverdrup        JONES CREEK
# 1  CEPSA IRAN PESADO  CEPSA ISTMO 32  CEPSA JOHAN SVERDRUP  CEPSA JONES CREEK
# 2      21 junio 2016    01 mayo 2014          febrero 2019  13 noviembre 2018
#
#                    JUB                   KIB                KOL  \
# 0        Jubilee Blend        Kissanje Blend               KOLE
# 1  CEPSA Jubilee Blend  Cepsa Kissanje Blend         CEPSA KOLE
# 2       27 agosto 2019         01 julio 2019  01 diciembre 2013
#
#                  KOM                  KUE                 LAE  \
# 0        KOLE MARINE        KUWAIT EXPORT        LAVAN EXPORT
# 1  CEPSA KOLE MARINE  CEPSA KUWAIT EXPORT  CEPSA LAVAN EXPORT
# 2      11 junio 2018         11 mayo 2008      16 agosto 2008
#
#                      LIV            LOK                 LUB            LUL  \
# 0        LIVERPOOL BLEND         LOKELE        LUCINA BLEND           LULA
# 1  CEPSA LIVERPOOL BLEND   CEPSA LOKELE  CEPSA LUCINA BLEND     CEPSA LULA
# 2                      0  17 julio 2019   01 diciembre 2006  01 junio 2012
#
#              MAN                 MAR            MAY                 MDN  \
# 0         MANDJI                MARS           MAYA            MEDANITO
# 1   CEPSA MANDJI          CEPSA MARS     CEPSA MAYA      CEPSA MEDANITO
# 2  01 junio 1995  10 septiembre 2012  01 julio 1992  13 septiembre 2018
#
#                  MEL            MRO              ME3                    MUR  \
# 0           MELLITAH           MERO          MESA 30        Murban Exp. Bld
# 1     CEPSA MELLITAH     CEPSA MERO    CEPSA MESA 30  CEPSA Murban Exp. Bld
# 2  29 noviembre 2017  01 junio 2018  01 octubre 1998        01 octubre 2009
#
#              NEM             NKO                 OGU            OKO  \
# 0          NEMBA          Nkossa            OGUENDJO          OKONO
# 1    CEPSA NEMBA    Cepsa Nkossa  CEPSA OGUENDJO (c)    CEPSA OKONO
# 2  01 enero 2013  25 agosto 2017       01 abril 2019  09 abril 2011
#
#                  OKR            OKW              OBE              OLE  \
# 0        OKORO LIGHT         OKWORI        OKWUIBOME        OLOMBENDO
# 1  CEPSA OKORO LIGHT   CEPSA OKWORI  CEPSA OKWUIBOME  CEPSA OLOMBENDO
# 2    06 febrero 2018  01 junio 2005  01 febrero 2016    01 marzo 2011
#
#                  OME            OSE              OTA                 PAZ  \
# 0        OMAN EXPORT        OSEBERG         OTAKIKPO             Pazflor
# 1  CEPSA OMAN EXPORT  CEPSA OSEBERG   CEPSA OTAKIKPO       Cepsa PAzflor
# 2      01 marzo 2017   20 mayo 2016  01 octubre 2017  16 septiembre 2011
#
#                  PEN              PIE             PLU              QAR  \
# 0         PENNINGTON           PIERCE        PLUTONIO            QARUN
# 1   CEPSA PENNINGTON     CEPSA PIERCE  CEPSA PLUTONIO  CEPSA QARUN NEW
# 2  11 noviembre 2016  12 febrero 2018   01 julio 2017    26 junio 2019
#
#               QUI                RAB                         REB  \
# 0        QUA IBOE         RABI BLEND        RUSSIAN EXPORT BLEND
# 1  CEPSA QUA IBOE   CEPSA RABI BLEND  CEPSA RUSSIAN EXPORT BLEND
# 2   01 enero 2018  01 diciembre 2003               01 enero 2002
#
#                    SAB            SKF             SAP                SMS  \
# 0        SAHARAN BLEND        SANKOFA        SAPINHOA              SARIR
# 1  CEPSA SAHARAN BLEND  CEPSA SANKOFA  CEPSA SAPINHOA        CEPSA SARIR
# 2           marzo 2021  14 julio 2017      enero 2013  17 noviembre 2015
#
#              SAT               SA1                 SCH                   SIL  \
# 0        SATURNO        SAXI BLEND        Schiehallion        SIBERIAN LIGHT
# 1  CEPSA SATURNO  CEPSA SAXI BLEND  CEPSA SCHIEHALLION  CEPSA SIBERIAN LIGHT
# 2  01 marzo 2013      01 mayo 2008   21 noviembre 2013    01 septiembre 1995
#
#              SIR            SNG            SOR              STA  \
# 0          SIRRI        SONGKLA       SOROOSH         STATFJORD
# 1    CEPSA SIRRI  CEPSA SONGKLA  CEPSA SOROOSH  CEPSA STATFJORD
# 2  07 marzo 2017              0  04 junio 2002    19 abril 2010
#
#                SUR              TEN               TER                    TIE  \
# 0           SURURU        TEN BLEND        TERRA NOVA        TI Epic/GrayOak
# 1     CEPSA SURURU  CEPSA TEN BLEND  CEPSA TERRA NOVA  CEPSA TI Epic/GrayOak
# 2  01 octubre 2019    01 enero 2017     01 junio 2014        21 febrero 2017
#
#                 TIP                TRO                       UZE  \
# 0        TI Permian        TROLL BLEND        Upper Zakum Exp Bl
# 1  CEPSA TI Permian  CEPSA TROLL BLEND  CEPSA UPPER ZAKUM EXP BL
# 2   21 febrero 2017      06 abril 2018             01 enero 2009
#
#                  URL               USB                VAR             VAS  \
# 0        URAL LIGERO        USAN Blend           VARANDEY        VASCONIA
# 1  CEPSA URAL LIGERO  CEPSA USAN BLEND     CEPSA VARANDEY  CEPSA VASCONIA
# 2      01 marzo 1988      01 mayo 2019  01 noviembre 2012   01 enero 2014
#
#                        WTC                    WML  \
# 0        WEST TEXAS CACTUS  West Texas Light 46.3
# 1  CEPSA WEST TEXAS CACTUS               WTXLT463
# 2          21 febrero 2017        30 octubre 2018
#
#                              WCS                   WED                 WHC  \
# 0         Western Canad'n Select        WESTERN DESERT        WHITE CLIFFS
# 1  CEPSA Western Canadian Select  CEPSA WESTERN DESERT  CEPSA WHITE CLIFFS
# 2              01 diciembre 2011         01 enero 2016   02 noviembre 2015
#
#                 WHR              WTL            YOH                 ZAB  \
# 0        WHITE ROSE        WTI LIGHT           YOHO        ZAFIRO BLEND
# 1  CEPSA WHITE ROSE  CEPSA WTI LIGHT     CEPSA YOHO  CEPSA ZAFIRO BLEND
# 2     01 enero 2014    31 enero 2019  01 enero 2018      01 agosto 2008
#
#                   ZAE                ZAR             ZUE  Unnamed: 154  \
# 0        ZAIRE EXPORT         ZARZAITINE        ZUEITINA           NaN
# 1  CEPSA ZAIRE EXPORT   CEPSA ZARZAITINE  CEPSA ZUEITINA           NaN
# 2       01 junio 1994  01 noviembre 2019               0           NaN
#
#    Unnamed: 155  Unnamed: 156  Unnamed: 157  Unnamed: 158  Unnamed: 159  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
#
#    Unnamed: 160
# 0           NaN
# 1           NaN
# 2           NaN

# %%
tags_crudos = ['ABO', 'AGB', 'AJE', 'AKP', 'AMB', 'ATA', 'AZE', 'BAU', 'BGA', 'BOL', 'BON',
              'BUZ', 'CAE', 'CEP', 'CJB', 'E44', 'E46', 'EGI', 'ERH', 'ESC', 'ESH', 'FOR',
              'GUL', 'IRA', 'JON', 'LIV', 'LOK', 'MEL', 'MRO', 'NKO', 'NOD', 'OBE', 'OKO', 
              'OKR', 'OKW', 'OTA', 'PEN', 'QAR', 'QUI', 'SAB', 'SAP', 'SKF', 'SUR', 'TIE', 
              'TIP', 'TRO', 'WML', 'WTC', 'WTL', 'YOH', 'ZAB']

properties_columns = ["TEXT", "API", "Den@15°C(g/cc)", "Sul(%w)","Overhead", "OH/KNA Swing", "Kero Naphtha",
                      "Kerosene","KE/GL Swing","Light Gasoil","LGL/GP Swing","Atmospheric Gasoil","Atmospheric Residue"]

# %%
df = df_assays_cd1[["TEXT"] + tags_crudos]
df = df.transpose().reset_index()
df.columns = df.iloc[0]
df = df.drop(df.index[0])
df = df[properties_columns]
df = df.T.reset_index().drop_duplicates(subset = 0, keep = "first").T
df.columns = df.iloc[0]
df = df.drop(df.index[0])
df.head(3)
# Out:
# 0 TEXT   API Den@15°C(g/cc) Sul(%w)  Overhead OH/KNA Swing Kero Naphtha  \
# 1  ABO  40.7         0.8211     0.1  0.284207     0.020301      0.03413
# 2  AGB  0.04         0.7868    0.04  0.321019      0.02332     0.042101
# 3  AJE  41.5         0.8174    0.03  0.199575     0.015355     0.028416
#
# 0  Kerosene KE/GL Swing Light Gasoil LGL/GP Swing Atmospheric Gasoil  \
# 1  0.095517    0.011388     0.319551     0.004254           0.049689
# 2  0.097527    0.011595     0.319068     0.004064           0.045924
# 3  0.050971    0.009326     0.388061     0.005304           0.065429
#
# 0 Atmospheric Residue
# 1            0.180964
# 2            0.135381
# 3            0.237562

# %%
cols_number = df.columns.tolist()
cols_number.remove("TEXT")

df_2 = df[cols_number].apply(pd.to_numeric)
df_2 = df_2.set_index(df.TEXT).reset_index()
df_2.dtypes
# Out:
# 0
# TEXT                    object
# API                    float64
# Den@15°C(g/cc)         float64
# Sul(%w)                float64
# Overhead               float64
# OH/KNA Swing           float64
# Kero Naphtha           float64
# Kerosene               float64
# KE/GL Swing            float64
# Light Gasoil           float64
# LGL/GP Swing           float64
# Atmospheric Gasoil     float64
# Atmospheric Residue    float64
# dtype: object

# %%
data_scaled = normalize(df_2[cols_number])
data_scaled = pd.DataFrame(data_scaled, columns=cols_number)
data_scaled.head()
# Out:
#         API  Den@15°C(g/cc)   Sul(%w)  Overhead  OH/KNA Swing  Kero Naphtha  \
# 0  0.999724        0.020169  0.002456  0.006981      0.000499      0.000838
# 1  0.043145        0.848661  0.043145  0.346259      0.025154      0.045411
# 2  0.999732        0.019691  0.000723  0.004808      0.000370      0.000685
# 3  0.999792        0.017413  0.001528  0.005829      0.000562      0.001010
# 4  0.999696        0.021276  0.002308  0.006596      0.000545      0.000893
#
#    Kerosene  KE/GL Swing  Light Gasoil  LGL/GP Swing  Atmospheric Gasoil  \
# 0  0.002346     0.000280      0.007849      0.000104            0.001221
# 1  0.105195     0.012507      0.344154      0.004384            0.049535
# 2  0.001228     0.000225      0.009348      0.000128            0.001576
# 3  0.001846     0.000225      0.007621      0.000090            0.001028
# 4  0.001832     0.000251      0.008085      0.000114            0.001404
#
#    Atmospheric Residue
# 0             0.004445
# 1             0.146025
# 2             0.005723
# 3             0.003618
# 4             0.005927

# %%
import scipy.cluster.hierarchy as shc
fig, ax = plt.subplots(figsize = (10, 7), constrained_layout = True)
ax.set_title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(data_scaled, method='ward', labels = df_2.TEXT))
# ax.set_xticklabels(df_2.TEXT)
plt.show();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-50b6ae746ddd> in <module>
#       2 fig, ax = plt.subplots(figsize = (10, 7), constrained_layout = True)
#       3 ax.set_title("Dendrograms")
# ----> 4 dend = shc.dendrogram(shc.linkage(data_scaled, method='ward', labels = df_2.TEXT))
#       5 # ax.set_xticklabels(df_2.TEXT)
#       6 plt.show();
#
# TypeError: linkage() got an unexpected keyword argument 'labels'

# %%
def plot_dendrogram(model, **kwargs):
    '''
    Esta función extrae la información de un modelo AgglomerativeClustering
    y representa su dendograma con la función dendogram de scipy.cluster.hierarchy
    '''
    
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack([model.children_, model.distances_,
                                      counts]).astype(float)

    # Plot
    dendrogram(linkage_matrix, **kwargs)

# %%
# Modelos
# ==============================================================================
modelo_hclust_complete = AgglomerativeClustering(
                            affinity = 'euclidean',
                            linkage  = 'complete',
                            distance_threshold = 0,
                            n_clusters         = None
                        )
modelo_hclust_complete.fit(X=X_scaled)

modelo_hclust_average = AgglomerativeClustering(
                            affinity = 'euclidean',
                            linkage  = 'average',
                            distance_threshold = 0,
                            n_clusters         = None
                        )
modelo_hclust_average.fit(X=X_scaled)

modelo_hclust_ward = AgglomerativeClustering(
                            affinity = 'euclidean',
                            linkage  = 'ward',
                            distance_threshold = 0,
                            n_clusters         = None
                     )
modelo_hclust_ward.fit(X=X_scaled)

# %%
# Dendrogramas
# ==============================================================================
fig, axs = plt.subplots(3, 1, figsize=(8, 8))
plot_dendrogram(modelo_hclust_average, color_threshold=0, ax=axs[0])
axs[0].set_title("Distancia euclídea, Linkage average")
plot_dendrogram(modelo_hclust_complete, color_threshold=0, ax=axs[1])
axs[1].set_title("Distancia euclídea, Linkage complete")
plot_dendrogram(modelo_hclust_ward, color_threshold=0, ax=axs[2])
axs[2].set_title("Distancia euclídea, Linkage ward")
plt.tight_layout();

# %%
cols_number = df.select_dtypes('number').columns.tolist()
X_scaled = scale(df[cols_number])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-56bffe045e92> in <module>
#       1 cols_number = df.select_dtypes('number').columns.tolist()
# ----> 2 X_scaled = scale(df[cols_number])
#
# ~\Anaconda3\envs\cdx_scipy\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\Anaconda3\envs\cdx_scipy\lib\site-packages\sklearn\preprocessing\_data.py in scale(X, axis, with_mean, with_std, copy)
#     161     X = check_array(X, accept_sparse='csc', copy=copy, ensure_2d=False,
#     162                     estimator='the scale function', dtype=FLOAT_DTYPES,
# --> 163                     force_all_finite='allow-nan')
#     164     if sparse.issparse(X):
#     165         if with_mean:
#
# ~\Anaconda3\envs\cdx_scipy\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\Anaconda3\envs\cdx_scipy\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     595
#     596         if all(isinstance(dtype, np.dtype) for dtype in dtypes_orig):
# --> 597             dtype_orig = np.result_type(*dtypes_orig)
#     598
#     599     if dtype_numeric:
#
# <__array_function__ internals> in result_type(*args, **kwargs)
#
# ValueError: at least one array or dtype is required
